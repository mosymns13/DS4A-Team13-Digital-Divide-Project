# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/jjruiz/Downloads/Internet_Subs_by_State.csv')
df2 = pd.read_csv('/Users/jjruiz/Downloads/Internet_Subs_by_State.csv', index_col = 0)

# %%
df.head()
# Out:
#         GEO_ID                  NAME                     S2801_C01_001E  \
# 0           id  Geographic Area Name  Estimate!!Total!!Total households
# 1  0400000US01               Alabama                            1897576
# 2  0400000US02                Alaska                             252199
# 3  0400000US04               Arizona                            2670441
# 4  0400000US05              Arkansas                            1163647
#
#                              S2801_C01_001M  \
# 0  Margin of Error!!Total!!Total households
# 1                                     10370
# 2                                      3658
# 3                                     12014
# 4                                      8530
#
#                                       S2801_C01_002E  \
# 0  Estimate!!Total!!Total households!!TYPES OF CO...
# 1                                            1696826
# 2                                             240277
# ...

# %%
df.shape
# Out:
# (53, 126)

# %% [markdown]
# df2.columns = df2.iloc[0]
# df2 = df2.iloc[1:].reset_index(drop=False)
# df2["GEO_ID"] = df2["GEO_ID"].astype(str)
# df2["GEO_ID"] = df2["GEO_ID"].str[7:11]
# df2 = df2.set_index('GEO_ID')
# df2.head()

# %%
df.columns = df.iloc[0]
df = df.iloc[1:].reset_index(drop=True)
df.head()
# Out:
# 0           id Geographic Area Name Estimate!!Total!!Total households  \
# 0  0400000US01              Alabama                           1897576
# 1  0400000US02               Alaska                            252199
# 2  0400000US04              Arizona                           2670441
# 3  0400000US05             Arkansas                           1163647
# 4  0400000US06           California                          13157873
#
# 0 Margin of Error!!Total!!Total households  \
# 0                                    10370
# 1                                     3658
# 2                                    12014
# 3                                     8530
# 4                                    23844
#
# 0 Estimate!!Total!!Total households!!TYPES OF COMPUTER!!Has one or more types of computing devices:  \
# 0                                            1696826
# 1                                             240277
# 2                                            2526296
# ...

# %%
df["id"] = df["id"].astype(str)
df["id"] = df["id"].str[7:11]
df.head()
# Out:
# 0    id Geographic Area Name Estimate!!Total!!Total households  \
# 0  US01              Alabama                           1897576
# 1  US02               Alaska                            252199
# 2  US04              Arizona                           2670441
# 3  US05             Arkansas                           1163647
# 4  US06           California                          13157873
#
# 0 Margin of Error!!Total!!Total households  \
# 0                                    10370
# 1                                     3658
# 2                                    12014
# 3                                     8530
# 4                                    23844
#
# 0 Estimate!!Total!!Total households!!TYPES OF COMPUTER!!Has one or more types of computing devices:  \
# 0                                            1696826
# 1                                             240277
# 2                                            2526296
# 3                                            1040974
# ...

# %%
df.columns = df.columns.str.lower().str.replace('!!', '_').str.replace(' ', '_').str.replace('-', '_').str.replace(':_', '_')

# %%
df.head()
# Out:
# 0    id geographic_area_name estimate_total_total_households  \
# 0  US01              Alabama                         1897576
# 1  US02               Alaska                          252199
# 2  US04              Arizona                         2670441
# 3  US05             Arkansas                         1163647
# 4  US06           California                        13157873
#
# 0 margin_of_error_total_total_households  \
# 0                                  10370
# 1                                   3658
# 2                                  12014
# 3                                   8530
# 4                                  23844
#
# 0 estimate_total_total_households_types_of_computer_has_one_or_more_types_of_computing_devices:  \
# 0                                            1696826
# 1                                             240277
# 2                                            2526296
# 3                                            1040974
# ...

# %%
df.shape
# Out:
# (52, 126)

# %%
rename_dict_short = {
    "id", "geographic_area_name", "estimate_total_households","margin_of_error_total_total_households",
    "Bucket_1", "ME_Bucket_1","Bucket_2", "ME_Bucket_2","Bucket_3", "ME_Bucket_3","Bucket_4", "ME_Bucket_4",
    "Bucket_5", "ME_Bucket_5","Bucket_6", "ME_Bucket_6","Bucket_7", "ME_Bucket_7","Bucket_8", "ME_Bucket_8",
    "Bucket_9", "ME_Bucket_9","Bucket_10", "ME_Bucket_10","Bucket_11", "ME_Bucket_11","Bucket_12", "ME_Bucket_12",
    "Bucket_13", "ME_Bucket_13","Bucket_14", "ME_Bucket_14","Bucket_15", "ME_Bucket_15","Bucket_16", "ME_Bucket_16",
    "Bucket_17", "ME_Bucket_17","Bucket_18", "ME_Bucket_18","Bucket_19", "ME_Bucket_19","Bucket_20", "ME_Bucket_20",
    "Bucket_21", "ME_Bucket_21","Bucket_22", "ME_Bucket_22","Bucket_23", "ME_Bucket_23","Bucket_24", "ME_Bucket_24",
    "Bucket_25", "ME_Bucket_25","Bucket_26", "ME_Bucket_26","Bucket_27", "ME_Bucket_27","Bucket_28", "ME_Bucket_28",
    "Bucket_29", "ME_Bucket_29","Bucket_30", "ME_Bucket_30",
    "Bucket_31", "ME_Bucket_31","Bucket_32", "ME_Bucket_32",
    "Bucket_33", "ME_Bucket_33","Bucket_34", "ME_Bucket_34",
    "Bucket_35", "ME_Bucket_35","Bucket_36", "ME_Bucket_36","Bucket_37","ME_Bucket_37","Bucket_38", "ME_Bucket_38",
    "Bucket_39", "ME_Bucket_39","Bucket_40", "ME_Bucket_40","Bucket_41","ME_Bucket_41","Bucket_42", "ME_Bucket_42",
    "Bucket_43", "ME_Bucket_43","Bucket_44", "ME_Bucket_44","Bucket_45","ME_Bucket_45","Bucket_46", "ME_Bucket_46",
    "Bucket_47", "ME_Bucket_47","Bucket_48", "ME_Bucket_48","Bucket_49", "ME_Bucket_49","Bucket_50", "ME_Bucket_50",
    "Bucket_51", "ME_Bucket_51","Bucket_52", "ME_Bucket_52","Bucket_53", "ME_Bucket_53","Bucket_54", "ME_Bucket_54",
    "Bucket_55", "ME_Bucket_55","Bucket_56", "ME_Bucket_56","Bucket_57", "ME_Bucket_57","Bucket_58", "ME_Bucket_58",
    "Bucket_59", "ME_Bucket_59","Bucket_60", "ME_Bucket_60",
}

# %%
df.set_axis([
    "id", "geographic_area_name", "estimate_total_households","margin_of_error_total_total_households",
    "Bucket_1", "ME_Bucket_1","Bucket_2", "ME_Bucket_2","Bucket_3", "ME_Bucket_3","Bucket_4", "ME_Bucket_4",
    "Bucket_5", "ME_Bucket_5","Bucket_6", "ME_Bucket_6","Bucket_7", "ME_Bucket_7","Bucket_8", "ME_Bucket_8",
    "Bucket_9", "ME_Bucket_9","Bucket_10", "ME_Bucket_10","Bucket_11", "ME_Bucket_11","Bucket_12", "ME_Bucket_12",
    "Bucket_13", "ME_Bucket_13","Bucket_14", "ME_Bucket_14","Bucket_15", "ME_Bucket_15","Bucket_16", "ME_Bucket_16",
    "Bucket_17", "ME_Bucket_17","Bucket_18", "ME_Bucket_18","Bucket_19", "ME_Bucket_19","Bucket_20", "ME_Bucket_20",
    "Bucket_21", "ME_Bucket_21","Bucket_22", "ME_Bucket_22","Bucket_23", "ME_Bucket_23","Bucket_24", "ME_Bucket_24",
    "Bucket_25", "ME_Bucket_25","Bucket_26", "ME_Bucket_26","Bucket_27", "ME_Bucket_27","Bucket_28", "ME_Bucket_28",
    "Bucket_29", "ME_Bucket_29","Bucket_30", "ME_Bucket_30",
    "Bucket_31", "ME_Bucket_31","Bucket_32", "ME_Bucket_32",
    "Bucket_33", "ME_Bucket_33","Bucket_34", "ME_Bucket_34",
    "Bucket_35", "ME_Bucket_35","Bucket_36", "ME_Bucket_36","Bucket_37","ME_Bucket_37","Bucket_38", "ME_Bucket_38",
    "Bucket_39", "ME_Bucket_39","Bucket_40", "ME_Bucket_40","Bucket_41","ME_Bucket_41","Bucket_42", "ME_Bucket_42",
    "Bucket_43", "ME_Bucket_43","Bucket_44", "ME_Bucket_44","Bucket_45","ME_Bucket_45","Bucket_46", "ME_Bucket_46",
    "Bucket_47", "ME_Bucket_47","Bucket_48", "ME_Bucket_48","Bucket_49", "ME_Bucket_49","Bucket_50", "ME_Bucket_50",
    "Bucket_51", "ME_Bucket_51","Bucket_52", "ME_Bucket_52","Bucket_53", "ME_Bucket_53","Bucket_54", "ME_Bucket_54",
    "Bucket_55", "ME_Bucket_55","Bucket_56", "ME_Bucket_56","Bucket_57", "ME_Bucket_57","Bucket_58", "ME_Bucket_58",
    "Bucket_59", "ME_Bucket_59","Bucket_60", "ME_Bucket_60","Bucket_61", "ME_Bucket_61"
], axis='columns', inplace =True)
df.head()
# Out:
#      id geographic_area_name estimate_total_households  \
# 0  US01              Alabama                   1897576
# 1  US02               Alaska                    252199
# 2  US04              Arizona                   2670441
# 3  US05             Arkansas                   1163647
# 4  US06           California                  13157873
#
#   margin_of_error_total_total_households  Bucket_1 ME_Bucket_1  Bucket_2  \
# 0                                  10370   1696826       11925   1297938
# 1                                   3658    240277        3657    198527
# 2                                  12014   2526296       12774   2126119
# 3                                   8530   1040974        9157    773212
# 4                                  23844  12513521       25055  10766546
#
#   ME_Bucket_2 Bucket_3 ME_Bucket_3  ... Bucket_57 ME_Bucket_57 Bucket_58  \
# 0       14225    66791        4017  ...      18.3          0.7       (X)
# ...

# %%
df = df.set_index('id')
df.head()
# Out:
#      geographic_area_name estimate_total_households  \
# id
# US01              Alabama                   1897576
# US02               Alaska                    252199
# US04              Arizona                   2670441
# US05             Arkansas                   1163647
# US06           California                  13157873
#
#      margin_of_error_total_total_households  Bucket_1 ME_Bucket_1  Bucket_2  \
# id
# US01                                  10370   1696826       11925   1297938
# US02                                   3658    240277        3657    198527
# US04                                  12014   2526296       12774   2126119
# US05                                   8530   1040974        9157    773212
# US06                                  23844  12513521       25055  10766546
#
#      ME_Bucket_2 Bucket_3 ME_Bucket_3  Bucket_4  ... Bucket_57 ME_Bucket_57  \
# id                                               ...
# ...

# %%
ME_df = df.filter([
    "ME_Bucket_1", "ME_Bucket_2","ME_Bucket_3","ME_Bucket_4",
     "ME_Bucket_5", "ME_Bucket_6","ME_Bucket_7", "ME_Bucket_8",
     "ME_Bucket_9","ME_Bucket_10","ME_Bucket_11", "ME_Bucket_12",
     "ME_Bucket_13","ME_Bucket_14", "ME_Bucket_15", "ME_Bucket_16",
     "ME_Bucket_17", "ME_Bucket_18", "ME_Bucket_19", "ME_Bucket_20",
     "ME_Bucket_21", "ME_Bucket_22", "ME_Bucket_23","ME_Bucket_24",
     "ME_Bucket_25", "ME_Bucket_26", "ME_Bucket_27", "ME_Bucket_28",
     "ME_Bucket_29","ME_Bucket_30","ME_Bucket_31", "ME_Bucket_32",
    "ME_Bucket_33", "ME_Bucket_34","ME_Bucket_35","ME_Bucket_36",
    "ME_Bucket_37","ME_Bucket_38","ME_Bucket_39","ME_Bucket_40",
    "ME_Bucket_41","ME_Bucket_42","ME_Bucket_43", "ME_Bucket_44",
    "ME_Bucket_45","ME_Bucket_46","ME_Bucket_47", "ME_Bucket_48", "ME_Bucket_49","ME_Bucket_50",
    "ME_Bucket_51", "ME_Bucket_52", "ME_Bucket_53","ME_Bucket_54","ME_Bucket_55","ME_Bucket_56", 
    "ME_Bucket_57","ME_Bucket_58","ME_Bucket_59","ME_Bucket_60","ME_Bucket_61"
], axis=1)
ME_df.head()

# %%
ME_df.head()
# Out:
#      ME_Bucket_1 ME_Bucket_2 ME_Bucket_3 ME_Bucket_4 ME_Bucket_5 ME_Bucket_6  \
# id
# US01       11925       14225        4017       13069        7972       13684
# US02        3657        4332        1181        3887        2705        4283
# US04       12774       14921        4408       14105        9790       17680
# US05        9157       11160        2893        9395        7998       11192
# US06       25055       30830       10538       28254       20002       35533
#
#      ME_Bucket_7 ME_Bucket_8 ME_Bucket_9 ME_Bucket_10  ... ME_Bucket_52  \
# id                                                     ...
# US01        2350        3536         450         7264  ...          1.4
# US02         404        1921         163         1252  ...          4.4
# US04        2661        4463         235         6021  ...          1.3
# US05        1523        2004         143         5336  ...          1.7
# US06        4238       11641         562        11937  ...          0.5
#
# ...

# %% [markdown]
# for column in df:
#     print(df[column])

# %%
data = [df1["A"], df2["A"]]

headers = ["df1", "df2"]

df3 = pd.concat(data, axis=1, keys=headers)
