# %% [markdown]
# # Analytical Dataset Exploration
#
# ## Date Created: 1/20/21
# ## Authors: Geri, Millie
#
# This notebook serves as a place to do data exploration on the `initial_analytic_dataset.csv` which holds all the variables of interest from each of our respective datasets. This is a place to look at the relationships between variables and other assumption checks.

# %%
#Packages import
#import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#import base64
#import c1applet.pairwise_boxplots as pairwise_boxplots
#import c1applet.pairwise_boxplots_gender as pairwise_boxplots_gender

#Note: You only need to import what you will be using in the notebook.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21112/3385867939.py in <module>
#       6 import numpy as np
#       7 #import base64
# ----> 8 import c1applet.pairwise_boxplots as pairwise_boxplots
#       9 import c1applet.pairwise_boxplots_gender as pairwise_boxplots_gender
#      10
#
# ModuleNotFoundError: No module named 'c1applet'

# %%
file = open("initial_analytic_dataset.csv", "r")
analytic_data = pd.read_csv("initial_analytic_dataset.csv")

# %%
analytic_data
# Out:
#                   id  pop_total              county        state   pop_class  \
# 0     0500000US01001    58805.0      Autauga County      Alabama  Metro Area
# 1     0500000US01003   231767.0      Baldwin County      Alabama  Metro Area
# 2     0500000US01005    25223.0      Barbour County      Alabama  Micro Area
# 3     0500000US01007    22293.0         Bibb County      Alabama  Micro Area
# 4     0500000US01009    59134.0       Blount County      Alabama  Metro Area
# ...              ...        ...                 ...          ...         ...
# 3217  0500000US72147     8249.0   Vieques Municipio  Puerto Rico  Rural Area
# 3218  0500000US72149    22093.0  Villalba Municipio  Puerto Rico  Micro Area
# 3219  0500000US72151    30426.0   Yabucoa Municipio  Puerto Rico  Micro Area
# 3220  0500000US72153    34172.0     Yauco Municipio  Puerto Rico  Micro Area
# 3221  0500000US02261        NaN                 NaN          NaN         NaN
#
#           state.1    year  broadband_pct  total_pop_enrolled  \
# 0         Alabama  2018.0          0.789                 NaN
# 1         Alabama  2018.0          0.781             35912.0
# 2         Alabama  2018.0          0.604                 NaN
# 3         Alabama  2018.0          0.661                 NaN
# 4         Alabama  2018.0          0.685                 NaN
# ...           ...     ...            ...                 ...
# 3217  Puerto Rico     NaN            NaN                 NaN
# 3218  Puerto Rico     NaN            NaN                 NaN
# 3219  Puerto Rico     NaN            NaN                 NaN
# 3220  Puerto Rico     NaN            NaN                 NaN
# 3221          NaN  2018.0          0.791                 NaN
#
#       percent_total_pop_enrolled  ...  est_total_households_with_no4  \
# 0                            NaN  ...                            NaN
# 1                           79.0  ...                        27152.0
# 2                            NaN  ...                            NaN
# 3                            NaN  ...                            NaN
# 4                            NaN  ...                            NaN
# ...                          ...  ...                            ...
# 3217                         NaN  ...                            NaN
# 3218                         NaN  ...                            NaN
# 3219                         NaN  ...                            NaN
# 3220                         NaN  ...                            NaN
# 3221                         NaN  ...                            NaN
#
#      est_total_households_none  est_total_households_with_sub  \
# 0                          NaN                            NaN
# 1                      17291.0                       153963.0
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# ...                        ...                            ...
# 3217                       NaN                            NaN
# 3218                       NaN                            NaN
# 3219                       NaN                            NaN
# 3220                       NaN                            NaN
# 3221                       NaN                            NaN
#
#       est_total_households_with_du  est_total_households_with_broadband  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
# ...                            ...                                  ...
# 3217                           NaN                                  NaN
# 3218                           NaN                                  NaN
# 3219                           NaN                                  NaN
# 3220                           NaN                                  NaN
# 3221                           NaN                                  NaN
#
#       est_total_households_with_cellular est_total_households_with_cell_no  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 3217                                 NaN                               NaN
# 3218                                 NaN                               NaN
# 3219                                 NaN                               NaN
# 3220                                 NaN                               NaN
# 3221                                 NaN                               NaN
#
#       est_total_households_with_cable  est_total_households_with_sat  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 3217                              NaN                            NaN
# 3218                              NaN                            NaN
# 3219                              NaN                            NaN
# 3220                              NaN                            NaN
# 3221                              NaN                            NaN
#
#       est_total_households_without_sub
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 3217                               NaN
# 3218                               NaN
# 3219                               NaN
# 3220                               NaN
# 3221                               NaN
#
# [3222 rows x 40 columns]

# %%
for col in analytic_data.columns:
    print(col)
# Out:
# id
# pop_total
# county
# state
# pop_class
# state.1
# year
# broadband_pct
# total_pop_enrolled
# percent_total_pop_enrolled
# margin_total_pop
# geo_id_x
# est_total_households_x
# est_med_income_households
# est_total_families
# est_med_income_families
# geo_id_y
# est_total_pop_16_over
# est_emp_pop_ratio_16_over
# est_unemp_pop_ratio_16_over
# geo_id
# est_total_households_y
# est_total_households_with_device
# est_total_households_with_desktop
# est_total_households_with_no
# est_total_households_with_smartphone
# est_total_households_with_no2
# est_total_households_with_portable
# est_total_households_with_no3
# est_total_households_with_other
# est_total_households_with_no4
# est_total_households_none
# est_total_households_with_sub
# est_total_households_with_du
# est_total_households_with_broadband
# est_total_households_with_cellular
# est_total_households_with_cell_no
# est_total_households_with_cable
# est_total_households_with_sat
# est_total_households_without_sub

# %% [markdown]
# Note from Millie: @JJ - Can you provide documentation onw hat the different "est_total_households_with_no" are? I am assuming that it mean no for a specific device, perhaps the one above, but I would like that confirmed.

# %%
analytic_data['est_unemp_pop_ratio_16_over']
# Out:
# 0       NaN
# 1       2.4
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 3217    NaN
# 3218    NaN
# 3219    NaN
# 3220    NaN
# 3221    NaN
# Name: est_unemp_pop_ratio_16_over, Length: 3222, dtype: float64

# %%
analytic_data["broadband_pct"] = analytic_data["broadband_pct"] *100
analytic_data["broadband_pct"]
# Out:
# 0       78.899997
# 1       78.099996
# 2       60.399997
# 3       66.100001
# 4       68.500000
#           ...
# 3217          NaN
# 3218          NaN
# 3219          NaN
# 3220          NaN
# 3221    79.100001
# Name: broadband_pct, Length: 3222, dtype: float64

# %%
analytic_data
# Out:
#                   id  pop_total              county        state   pop_class  \
# 0     0500000US01001    58805.0      Autauga County      Alabama  Metro Area
# 1     0500000US01003   231767.0      Baldwin County      Alabama  Metro Area
# 2     0500000US01005    25223.0      Barbour County      Alabama  Micro Area
# 3     0500000US01007    22293.0         Bibb County      Alabama  Micro Area
# 4     0500000US01009    59134.0       Blount County      Alabama  Metro Area
# ...              ...        ...                 ...          ...         ...
# 3217  0500000US72147     8249.0   Vieques Municipio  Puerto Rico  Rural Area
# 3218  0500000US72149    22093.0  Villalba Municipio  Puerto Rico  Micro Area
# 3219  0500000US72151    30426.0   Yabucoa Municipio  Puerto Rico  Micro Area
# 3220  0500000US72153    34172.0     Yauco Municipio  Puerto Rico  Micro Area
# 3221  0500000US02261        NaN                 NaN          NaN         NaN
#
#           state.1    year  broadband_pct  total_pop_enrolled  \
# 0         Alabama  2018.0      78.899997                 NaN
# 1         Alabama  2018.0      78.099996             35912.0
# 2         Alabama  2018.0      60.399997                 NaN
# 3         Alabama  2018.0      66.100001                 NaN
# 4         Alabama  2018.0      68.500000                 NaN
# ...           ...     ...            ...                 ...
# 3217  Puerto Rico     NaN            NaN                 NaN
# 3218  Puerto Rico     NaN            NaN                 NaN
# 3219  Puerto Rico     NaN            NaN                 NaN
# 3220  Puerto Rico     NaN            NaN                 NaN
# 3221          NaN  2018.0      79.100001                 NaN
#
#       percent_total_pop_enrolled  ...  est_total_households_with_no4  \
# 0                            NaN  ...                            NaN
# 1                           79.0  ...                        27152.0
# 2                            NaN  ...                            NaN
# 3                            NaN  ...                            NaN
# 4                            NaN  ...                            NaN
# ...                          ...  ...                            ...
# 3217                         NaN  ...                            NaN
# 3218                         NaN  ...                            NaN
# 3219                         NaN  ...                            NaN
# 3220                         NaN  ...                            NaN
# 3221                         NaN  ...                            NaN
#
#      est_total_households_none  est_total_households_with_sub  \
# 0                          NaN                            NaN
# 1                      17291.0                       153963.0
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# ...                        ...                            ...
# 3217                       NaN                            NaN
# 3218                       NaN                            NaN
# 3219                       NaN                            NaN
# 3220                       NaN                            NaN
# 3221                       NaN                            NaN
#
#       est_total_households_with_du  est_total_households_with_broadband  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
# ...                            ...                                  ...
# 3217                           NaN                                  NaN
# 3218                           NaN                                  NaN
# 3219                           NaN                                  NaN
# 3220                           NaN                                  NaN
# 3221                           NaN                                  NaN
#
#       est_total_households_with_cellular est_total_households_with_cell_no  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 3217                                 NaN                               NaN
# 3218                                 NaN                               NaN
# 3219                                 NaN                               NaN
# 3220                                 NaN                               NaN
# 3221                                 NaN                               NaN
#
#       est_total_households_with_cable  est_total_households_with_sat  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 3217                              NaN                            NaN
# 3218                              NaN                            NaN
# 3219                              NaN                            NaN
# 3220                              NaN                            NaN
# 3221                              NaN                            NaN
#
#       est_total_households_without_sub
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 3217                               NaN
# 3218                               NaN
# 3219                               NaN
# 3220                               NaN
# 3221                               NaN
#
# [3222 rows x 40 columns]

# %% [markdown]
# ### Broadband Percent v. Percent Total Population Enrolled

# %%
analytic_data["broadband_pct"].plot.hist(figsize=(15, 5))
plt.title("Broadband Percentage Distribution")
plt.xlabel("Broadband Percentage")
# Out:
# Text(0.5, 0, 'Broadband Percentage')

# %%
analytic_data["percent_total_pop_enrolled"].plot.hist(figsize=(15, 5))
plt.title("Total Population Enrolled")
plt.xlabel("Total Pop Enrolled")
# Out:
# Text(0.5, 0, 'Total Pop Enrolled')

# %%
plt.scatter(x = analytic_data["broadband_pct"], y = analytic_data["percent_total_pop_enrolled"]) # The plot
plt.title("Population Enrolled vs Broadband Percentage") # Adding a title
plt.xlabel("Broadband Percentage") # Adding axis labels
plt.ylabel("Total Population Enrolled")
# Out:
# Text(0, 0.5, 'Total Population Enrolled')

# %%
#Note from Millie: I added this plot because I thought it might be more useful than looking at three different plots
sns.jointplot(data = analytic_data, x = "broadband_pct", y = "percent_total_pop_enrolled", height = 8);

# %% [markdown]
# ### Distrubution of Devices in Households
#
# For now, looking at all households with some sort of device against total households.

# %%
#selecting certian variables
devices_in_hh = analytic_data[['id','est_total_households_y',
'est_total_households_with_device',
'est_total_households_with_desktop',
'est_total_households_with_smartphone',
'est_total_households_with_portable',
'est_total_households_with_other',
'est_total_households_none']]

# %%
#choosing columns to pivot
to_pivot = devices_in_hh[[
'est_total_households_with_device',
'est_total_households_with_desktop',
'est_total_households_with_smartphone',
'est_total_households_with_portable']]

#reshaping data
plot_devices_df = pd.melt(devices_in_hh, id_vars = 'id', value_vars = to_pivot, var_name = "type", value_name = "value")

#creating a separate value column to place decimal in different place
plot_devices_df['value2'] = plot_devices_df['value']*.001

# %%
plot_devices_df.describe()
# Out:
#               value       value2
# count  3.284000e+03  3284.000000
# mean   2.689772e+04    26.897725
# std    5.226474e+04    52.264741
# min    2.178000e+03     2.178000
# 25%    6.914000e+03     6.914000
# 50%    1.214100e+04    12.141000
# 75%    2.669300e+04    26.693000
# max    1.348569e+06  1348.569000

# %% [markdown]
# There is a huge std and data is heavily skewed to the right.

# %%
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
g = sns.FacetGrid(plot_devices_df, row="type", aspect=9, height=1.2, palette = pal)

g.map_dataframe(sns.kdeplot, x="value2", fill=True, alpha=1)
g.map_dataframe(sns.kdeplot, x="value2", color='black')
g.fig.subplots_adjust(hspace=-.5)


g.set_titles("")
g.set(yticks=[])
g.despine(left=True)

# %% [markdown]
# ### Employment Data Distribution

# %%
employment_info = analytic_data[['id', 'est_total_pop_16_over', 'est_emp_pop_ratio_16_over', 
                                 'est_unemp_pop_ratio_16_over']]

plot_employ_df = pd.melt(employment_info, id_vars = 'id', value_vars = ['est_emp_pop_ratio_16_over', 
                                 'est_unemp_pop_ratio_16_over'], var_name = "type", value_name = "value")

plot_employ_df['value2'] = plot_devices_df['value']*.001

plot_employ_df.describe()
# Out:
#              value       value2
# count  1642.000000  1642.000000
# mean     31.830390    20.399951
# std      27.257013    35.263328
# min       1.100000     2.178000
# 25%       4.600000     5.733000
# 50%      24.800000     9.967500
# 75%      59.175000    21.804000
# max      76.500000   701.010000

# %%
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
g = sns.FacetGrid(plot_employ_df, row="type", aspect=9, height=1.2, palette = pal)

g.map_dataframe(sns.kdeplot, x="value", fill=True, alpha=1)
g.map_dataframe(sns.kdeplot, x="value", color='black')
g.fig.subplots_adjust(hspace=-.5)


g.set_titles("")
g.set(yticks=[])
g.despine(left=True)

# %% [markdown]
# Density plot above is incomplete. Currently troubleshooting.
#
# References for facet density plot:
# - https://seaborn.pydata.org/examples/kde_ridgeplot.html
# - https://python.plainenglish.io/ridge-plots-with-pythons-seaborn-4de5725881af

# %% [markdown]
# ### Unemployment and Broadband Percent

# %%
sns.jointplot(data = analytic_data, x = "broadband_pct", y = "est_unemp_pop_ratio_16_over", 
              kind = "hex", height = 8);

# %%
sns.jointplot(data = analytic_data, x = "broadband_pct", y = "est_unemp_pop_ratio_16_over", 
              kind = "reg", height = 8);

# %%
analytic_data
# Out:
#                   id  pop_total              county        state   pop_class  \
# 0     0500000US01001    58805.0      Autauga County      Alabama  Metro Area
# 1     0500000US01003   231767.0      Baldwin County      Alabama  Metro Area
# 2     0500000US01005    25223.0      Barbour County      Alabama  Micro Area
# 3     0500000US01007    22293.0         Bibb County      Alabama  Micro Area
# 4     0500000US01009    59134.0       Blount County      Alabama  Metro Area
# ...              ...        ...                 ...          ...         ...
# 3217  0500000US72147     8249.0   Vieques Municipio  Puerto Rico  Rural Area
# 3218  0500000US72149    22093.0  Villalba Municipio  Puerto Rico  Micro Area
# 3219  0500000US72151    30426.0   Yabucoa Municipio  Puerto Rico  Micro Area
# 3220  0500000US72153    34172.0     Yauco Municipio  Puerto Rico  Micro Area
# 3221  0500000US02261        NaN                 NaN          NaN         NaN
#
#           state.1    year  broadband_pct  total_pop_enrolled  \
# 0         Alabama  2018.0      78.899997                 NaN
# 1         Alabama  2018.0      78.099996             35912.0
# 2         Alabama  2018.0      60.399997                 NaN
# 3         Alabama  2018.0      66.100001                 NaN
# 4         Alabama  2018.0      68.500000                 NaN
# ...           ...     ...            ...                 ...
# 3217  Puerto Rico     NaN            NaN                 NaN
# 3218  Puerto Rico     NaN            NaN                 NaN
# 3219  Puerto Rico     NaN            NaN                 NaN
# 3220  Puerto Rico     NaN            NaN                 NaN
# 3221          NaN  2018.0      79.100001                 NaN
#
#       percent_total_pop_enrolled  ...  est_total_households_with_no4  \
# 0                            NaN  ...                            NaN
# 1                           79.0  ...                        27152.0
# 2                            NaN  ...                            NaN
# 3                            NaN  ...                            NaN
# 4                            NaN  ...                            NaN
# ...                          ...  ...                            ...
# 3217                         NaN  ...                            NaN
# 3218                         NaN  ...                            NaN
# 3219                         NaN  ...                            NaN
# 3220                         NaN  ...                            NaN
# 3221                         NaN  ...                            NaN
#
#      est_total_households_none  est_total_households_with_sub  \
# 0                          NaN                            NaN
# 1                      17291.0                       153963.0
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# ...                        ...                            ...
# 3217                       NaN                            NaN
# 3218                       NaN                            NaN
# 3219                       NaN                            NaN
# 3220                       NaN                            NaN
# 3221                       NaN                            NaN
#
#       est_total_households_with_du  est_total_households_with_broadband  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
# ...                            ...                                  ...
# 3217                           NaN                                  NaN
# 3218                           NaN                                  NaN
# 3219                           NaN                                  NaN
# 3220                           NaN                                  NaN
# 3221                           NaN                                  NaN
#
#       est_total_households_with_cellular est_total_households_with_cell_no  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 3217                                 NaN                               NaN
# 3218                                 NaN                               NaN
# 3219                                 NaN                               NaN
# 3220                                 NaN                               NaN
# 3221                                 NaN                               NaN
#
#       est_total_households_with_cable  est_total_households_with_sat  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 3217                              NaN                            NaN
# 3218                              NaN                            NaN
# 3219                              NaN                            NaN
# 3220                              NaN                            NaN
# 3221                              NaN                            NaN
#
#       est_total_households_without_sub
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 3217                               NaN
# 3218                               NaN
# 3219                               NaN
# 3220                               NaN
# 3221                               NaN
#
# [3222 rows x 40 columns]

# %% [markdown]
# ### Adding Region Dimension to the Analytic Data
#
# This is to make it easier to breakdown the data visuals so we are not looking at the entire country on one level. All visuals below are exploring with region column.

# %%
regions = pd.read_csv("https://raw.githubusercontent.com/cphalpert/census-regions/master/us%20census%20bureau%20regions%20and%20divisions.csv")
regions.columns = regions.columns.str.lower().str.replace(" ", "_")
regions
# Out:
#                    state state_code     region            division
# 0                 Alaska         AK       West             Pacific
# 1                Alabama         AL      South  East South Central
# 2               Arkansas         AR      South  West South Central
# 3                Arizona         AZ       West            Mountain
# 4             California         CA       West             Pacific
# 5               Colorado         CO       West            Mountain
# 6            Connecticut         CT  Northeast         New England
# 7   District of Columbia         DC      South      South Atlantic
# 8               Delaware         DE      South      South Atlantic
# 9                Florida         FL      South      South Atlantic
# 10               Georgia         GA      South      South Atlantic
# 11                Hawaii         HI       West             Pacific
# 12                  Iowa         IA    Midwest  West North Central
# 13                 Idaho         ID       West            Mountain
# 14              Illinois         IL    Midwest  East North Central
# 15               Indiana         IN    Midwest  East North Central
# 16                Kansas         KS    Midwest  West North Central
# 17              Kentucky         KY      South  East South Central
# 18             Louisiana         LA      South  West South Central
# 19         Massachusetts         MA  Northeast         New England
# 20              Maryland         MD      South      South Atlantic
# 21                 Maine         ME  Northeast         New England
# 22              Michigan         MI    Midwest  East North Central
# 23             Minnesota         MN    Midwest  West North Central
# 24              Missouri         MO    Midwest  West North Central
# 25           Mississippi         MS      South  East South Central
# 26               Montana         MT       West            Mountain
# 27        North Carolina         NC      South      South Atlantic
# 28          North Dakota         ND    Midwest  West North Central
# 29              Nebraska         NE    Midwest  West North Central
# 30         New Hampshire         NH  Northeast         New England
# 31            New Jersey         NJ  Northeast     Middle Atlantic
# 32            New Mexico         NM       West            Mountain
# 33                Nevada         NV       West            Mountain
# 34              New York         NY  Northeast     Middle Atlantic
# 35                  Ohio         OH    Midwest  East North Central
# 36              Oklahoma         OK      South  West South Central
# 37                Oregon         OR       West             Pacific
# 38          Pennsylvania         PA  Northeast     Middle Atlantic
# 39          Rhode Island         RI  Northeast         New England
# 40        South Carolina         SC      South      South Atlantic
# 41          South Dakota         SD    Midwest  West North Central
# 42             Tennessee         TN      South  East South Central
# 43                 Texas         TX      South  West South Central
# 44                  Utah         UT       West            Mountain
# 45              Virginia         VA      South      South Atlantic
# 46               Vermont         VT  Northeast         New England
# 47            Washington         WA       West             Pacific
# 48             Wisconsin         WI    Midwest  East North Central
# 49         West Virginia         WV      South      South Atlantic
# 50               Wyoming         WY       West            Mountain

# %%
revised_analytic_data = analytic_data.merge(regions, left_on = "state", right_on = "state", how = "outer")

# %%
revised_analytic_data
# Out:
#                   id  pop_total              county        state   pop_class  \
# 0     0500000US01001    58805.0      Autauga County      Alabama  Metro Area
# 1     0500000US01003   231767.0      Baldwin County      Alabama  Metro Area
# 2     0500000US01005    25223.0      Barbour County      Alabama  Micro Area
# 3     0500000US01007    22293.0         Bibb County      Alabama  Micro Area
# 4     0500000US01009    59134.0       Blount County      Alabama  Metro Area
# ...              ...        ...                 ...          ...         ...
# 3217  0500000US72147     8249.0   Vieques Municipio  Puerto Rico  Rural Area
# 3218  0500000US72149    22093.0  Villalba Municipio  Puerto Rico  Micro Area
# 3219  0500000US72151    30426.0   Yabucoa Municipio  Puerto Rico  Micro Area
# 3220  0500000US72153    34172.0     Yauco Municipio  Puerto Rico  Micro Area
# 3221  0500000US02261        NaN                 NaN          NaN         NaN
#
#           state.1    year  broadband_pct  total_pop_enrolled  \
# 0         Alabama  2018.0      78.899997                 NaN
# 1         Alabama  2018.0      78.099996             35912.0
# 2         Alabama  2018.0      60.399997                 NaN
# 3         Alabama  2018.0      66.100001                 NaN
# 4         Alabama  2018.0      68.500000                 NaN
# ...           ...     ...            ...                 ...
# 3217  Puerto Rico     NaN            NaN                 NaN
# 3218  Puerto Rico     NaN            NaN                 NaN
# 3219  Puerto Rico     NaN            NaN                 NaN
# 3220  Puerto Rico     NaN            NaN                 NaN
# 3221          NaN  2018.0      79.100001                 NaN
#
#       percent_total_pop_enrolled  ...  est_total_households_with_du  \
# 0                            NaN  ...                           NaN
# 1                           79.0  ...                           NaN
# 2                            NaN  ...                           NaN
# 3                            NaN  ...                           NaN
# 4                            NaN  ...                           NaN
# ...                          ...  ...                           ...
# 3217                         NaN  ...                           NaN
# 3218                         NaN  ...                           NaN
# 3219                         NaN  ...                           NaN
# 3220                         NaN  ...                           NaN
# 3221                         NaN  ...                           NaN
#
#      est_total_households_with_broadband  est_total_households_with_cellular  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# ...                                  ...                                 ...
# 3217                                 NaN                                 NaN
# 3218                                 NaN                                 NaN
# 3219                                 NaN                                 NaN
# 3220                                 NaN                                 NaN
# 3221                                 NaN                                 NaN
#
#       est_total_households_with_cell_no  est_total_households_with_cable  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
# ...                                 ...                              ...
# 3217                                NaN                              NaN
# 3218                                NaN                              NaN
# 3219                                NaN                              NaN
# 3220                                NaN                              NaN
# 3221                                NaN                              NaN
#
#       est_total_households_with_sat est_total_households_without_sub  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
# ...                             ...                              ...
# 3217                            NaN                              NaN
# 3218                            NaN                              NaN
# 3219                            NaN                              NaN
# 3220                            NaN                              NaN
# 3221                            NaN                              NaN
#
#       state_code  region            division
# 0             AL   South  East South Central
# 1             AL   South  East South Central
# 2             AL   South  East South Central
# 3             AL   South  East South Central
# 4             AL   South  East South Central
# ...          ...     ...                 ...
# 3217         NaN     NaN                 NaN
# 3218         NaN     NaN                 NaN
# 3219         NaN     NaN                 NaN
# 3220         NaN     NaN                 NaN
# 3221         NaN     NaN                 NaN
#
# [3222 rows x 43 columns]

# %%
sns.jointplot(data = revised_analytic_data, x = "broadband_pct", y = "est_unemp_pop_ratio_16_over", 
             hue = "region", height = 8);

# %%
#broadband percent
bb_region = revised_analytic_data[['id', 'region', 'broadband_pct']]
sns.displot(
    bb_region, x="broadband_pct", col="region",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)

# %%
#umemployment ratio
sns.displot(
    revised_analytic_data, x="est_unemp_pop_ratio_16_over", col="region",
    height=3, facet_kws=dict(margin_titles=True),
)

# %%
#creating a separate value column to place decimal in different place
revised_analytic_data['x_est_med_income_households'] = revised_analytic_data['est_med_income_households']*.001

#median income
sns.displot(
    revised_analytic_data, x="x_est_med_income_households", col="region",
    height=3, facet_kws=dict(margin_titles=True),
)

# %% [markdown]
# # Analyzing Population Classification
# Many Rural and Micro Areas do not have Census data for most of our data. Therefore, for smaller, more rural areas, we can only look at broadband data. We may consider breaking down the Metro Areas into different bins.

# %%
sns.jointplot(data = revised_analytic_data, x = "pop_total", y = "broadband_pct", 
             hue = "pop_class");

# %%
#creating a separate value column to place decimal in different place
revised_analytic_data['broadband_pct'] = revised_analytic_data['broadband_pct']

#median income
sns.displot(
    revised_analytic_data, x="broadband_pct", col="pop_class",
    height=3, facet_kws=dict(margin_titles=True),
)

# %% [markdown]
# ##Broadband Dataset Classification

# %%
revised_analytic_data
# Out:
#                   id  pop_total              county        state   pop_class  \
# 0     0500000US01001    58805.0      Autauga County      Alabama  Metro Area
# 1     0500000US01003   231767.0      Baldwin County      Alabama  Metro Area
# 2     0500000US01005    25223.0      Barbour County      Alabama  Micro Area
# 3     0500000US01007    22293.0         Bibb County      Alabama  Micro Area
# 4     0500000US01009    59134.0       Blount County      Alabama  Metro Area
# ...              ...        ...                 ...          ...         ...
# 3217  0500000US72147     8249.0   Vieques Municipio  Puerto Rico  Rural Area
# 3218  0500000US72149    22093.0  Villalba Municipio  Puerto Rico  Micro Area
# 3219  0500000US72151    30426.0   Yabucoa Municipio  Puerto Rico  Micro Area
# 3220  0500000US72153    34172.0     Yauco Municipio  Puerto Rico  Micro Area
# 3221  0500000US02261        NaN                 NaN          NaN         NaN
#
#           state.1    year  broadband_pct  total_pop_enrolled  \
# 0         Alabama  2018.0      78.899997                 NaN
# 1         Alabama  2018.0      78.099996             35912.0
# 2         Alabama  2018.0      60.399997                 NaN
# 3         Alabama  2018.0      66.100001                 NaN
# 4         Alabama  2018.0      68.500000                 NaN
# ...           ...     ...            ...                 ...
# 3217  Puerto Rico     NaN            NaN                 NaN
# 3218  Puerto Rico     NaN            NaN                 NaN
# 3219  Puerto Rico     NaN            NaN                 NaN
# 3220  Puerto Rico     NaN            NaN                 NaN
# 3221          NaN  2018.0      79.100001                 NaN
#
#       percent_total_pop_enrolled  ...  est_total_households_with_broadband  \
# 0                            NaN  ...                                  NaN
# 1                           79.0  ...                                  NaN
# 2                            NaN  ...                                  NaN
# 3                            NaN  ...                                  NaN
# 4                            NaN  ...                                  NaN
# ...                          ...  ...                                  ...
# 3217                         NaN  ...                                  NaN
# 3218                         NaN  ...                                  NaN
# 3219                         NaN  ...                                  NaN
# 3220                         NaN  ...                                  NaN
# 3221                         NaN  ...                                  NaN
#
#      est_total_households_with_cellular  est_total_households_with_cell_no  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 3217                                NaN                                NaN
# 3218                                NaN                                NaN
# 3219                                NaN                                NaN
# 3220                                NaN                                NaN
# 3221                                NaN                                NaN
#
#       est_total_households_with_cable  est_total_households_with_sat  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 3217                              NaN                            NaN
# 3218                              NaN                            NaN
# 3219                              NaN                            NaN
# 3220                              NaN                            NaN
# 3221                              NaN                            NaN
#
#       est_total_households_without_sub state_code  region            division  \
# 0                                  NaN         AL   South  East South Central
# 1                                  NaN         AL   South  East South Central
# 2                                  NaN         AL   South  East South Central
# 3                                  NaN         AL   South  East South Central
# 4                                  NaN         AL   South  East South Central
# ...                                ...        ...     ...                 ...
# 3217                               NaN        NaN     NaN                 NaN
# 3218                               NaN        NaN     NaN                 NaN
# 3219                               NaN        NaN     NaN                 NaN
# 3220                               NaN        NaN     NaN                 NaN
# 3221                               NaN        NaN     NaN                 NaN
#
#       x_est_med_income_households
# 0                             NaN
# 1                          56.813
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 3217                          NaN
# 3218                          NaN
# 3219                          NaN
# 3220                          NaN
# 3221                          NaN
#
# [3222 rows x 44 columns]

# %%
revised_analytic_data["broadband_pct"].describe()
# Out:
# count    3133.000000
# mean       72.691733
# std         9.251261
# min        25.700000
# 25%        67.400002
# 50%        73.600000
# 75%        78.800005
# max        95.499998
# Name: broadband_pct, dtype: float64

# %%
#creating broadband classification
def bdbd_type(broadband_pct):
    """Assign labels to county according to their broadband pct
    """
    if broadband_pct < 25.7:
        label = "1"
    elif broadband_pct < 67.4: #Between 10,000 to 49,999
        label = "2"
    elif broadband_pct < 73.6: #Between 10,000 to 49,999
        label = "3"
    elif broadband_pct < 78.8: #Between 10,000 to 49,999
        label = "4"
    elif broadband_pct > 78.8: #Between 10,000 to 49,999
        label = "5"    
    else: #Greater than 50k
        label = "1"
    return label

# %%
revised_analytic_data["bdbd_score"] = revised_analytic_data["broadband_pct"].apply(bdbd_type)

# %%
revised_analytic_data
# Out:
#                   id  pop_total              county        state   pop_class  \
# 0     0500000US01001    58805.0      Autauga County      Alabama  Metro Area
# 1     0500000US01003   231767.0      Baldwin County      Alabama  Metro Area
# 2     0500000US01005    25223.0      Barbour County      Alabama  Micro Area
# 3     0500000US01007    22293.0         Bibb County      Alabama  Micro Area
# 4     0500000US01009    59134.0       Blount County      Alabama  Metro Area
# ...              ...        ...                 ...          ...         ...
# 3217  0500000US72147     8249.0   Vieques Municipio  Puerto Rico  Rural Area
# 3218  0500000US72149    22093.0  Villalba Municipio  Puerto Rico  Micro Area
# 3219  0500000US72151    30426.0   Yabucoa Municipio  Puerto Rico  Micro Area
# 3220  0500000US72153    34172.0     Yauco Municipio  Puerto Rico  Micro Area
# 3221  0500000US02261        NaN                 NaN          NaN         NaN
#
#           state.1    year  broadband_pct  total_pop_enrolled  \
# 0         Alabama  2018.0      78.899997                 NaN
# 1         Alabama  2018.0      78.099996             35912.0
# 2         Alabama  2018.0      60.399997                 NaN
# 3         Alabama  2018.0      66.100001                 NaN
# 4         Alabama  2018.0      68.500000                 NaN
# ...           ...     ...            ...                 ...
# 3217  Puerto Rico     NaN            NaN                 NaN
# 3218  Puerto Rico     NaN            NaN                 NaN
# 3219  Puerto Rico     NaN            NaN                 NaN
# 3220  Puerto Rico     NaN            NaN                 NaN
# 3221          NaN  2018.0      79.100001                 NaN
#
#       percent_total_pop_enrolled  ...  est_total_households_with_cellular  \
# 0                            NaN  ...                                 NaN
# 1                           79.0  ...                                 NaN
# 2                            NaN  ...                                 NaN
# 3                            NaN  ...                                 NaN
# 4                            NaN  ...                                 NaN
# ...                          ...  ...                                 ...
# 3217                         NaN  ...                                 NaN
# 3218                         NaN  ...                                 NaN
# 3219                         NaN  ...                                 NaN
# 3220                         NaN  ...                                 NaN
# 3221                         NaN  ...                                 NaN
#
#      est_total_households_with_cell_no  est_total_households_with_cable  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# ...                                ...                              ...
# 3217                               NaN                              NaN
# 3218                               NaN                              NaN
# 3219                               NaN                              NaN
# 3220                               NaN                              NaN
# 3221                               NaN                              NaN
#
#       est_total_households_with_sat  est_total_households_without_sub  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# ...                             ...                               ...
# 3217                            NaN                               NaN
# 3218                            NaN                               NaN
# 3219                            NaN                               NaN
# 3220                            NaN                               NaN
# 3221                            NaN                               NaN
#
#       state_code region            division  x_est_med_income_households  \
# 0             AL  South  East South Central                          NaN
# 1             AL  South  East South Central                       56.813
# 2             AL  South  East South Central                          NaN
# 3             AL  South  East South Central                          NaN
# 4             AL  South  East South Central                          NaN
# ...          ...    ...                 ...                          ...
# 3217         NaN    NaN                 NaN                          NaN
# 3218         NaN    NaN                 NaN                          NaN
# 3219         NaN    NaN                 NaN                          NaN
# 3220         NaN    NaN                 NaN                          NaN
# 3221         NaN    NaN                 NaN                          NaN
#
#       bdbd_score
# 0              5
# 1              4
# 2              2
# 3              2
# 4              3
# ...          ...
# 3217           1
# 3218           1
# 3219           1
# 3220           1
# 3221           5
#
# [3222 rows x 45 columns]

# %%
bdbd_df = revised_analytic_data[["county", "state","pop_total", "pop_class", "broadband_pct", "bdbd_score"]]
bdbd_df
# Out:
#                   county        state  pop_total   pop_class  broadband_pct  \
# 0         Autauga County      Alabama    58805.0  Metro Area      78.899997
# 1         Baldwin County      Alabama   231767.0  Metro Area      78.099996
# 2         Barbour County      Alabama    25223.0  Micro Area      60.399997
# 3            Bibb County      Alabama    22293.0  Micro Area      66.100001
# 4          Blount County      Alabama    59134.0  Metro Area      68.500000
# ...                  ...          ...        ...         ...            ...
# 3217   Vieques Municipio  Puerto Rico     8249.0  Rural Area            NaN
# 3218  Villalba Municipio  Puerto Rico    22093.0  Micro Area            NaN
# 3219   Yabucoa Municipio  Puerto Rico    30426.0  Micro Area            NaN
# 3220     Yauco Municipio  Puerto Rico    34172.0  Micro Area            NaN
# 3221                 NaN          NaN        NaN         NaN      79.100001
#
#      bdbd_score
# 0             5
# 1             4
# 2             2
# 3             2
# 4             3
# ...         ...
# 3217          1
# 3218          1
# 3219          1
# 3220          1
# 3221          5
#
# [3222 rows x 6 columns]

# %%
bdbd_df = revised_analytic_data[["county", "state","pop_total", "pop_class", "broadband_pct", "bdbd_score"]]
bdbd_df
# Out:
# 5    790
# 4    785
# 2    779
# 3    779
# 1     89
# Name: bdbd_score, dtype: int64

# %%
corrz = bdbd_df.corr()
corrz
# Out:
#                pop_total  broadband_pct
# pop_total       1.000000       0.268957
# broadband_pct   0.268957       1.000000

# %%
my_contingency_table = pd.crosstab(index=bdbd_df["pop_class"], columns=bdbd_df["bdbd_score"])
my_contingency_table
# Out:
# bdbd_score   1    2    3    4    5
# pop_class
# Metro Area  15   43  126  267  554
# Micro Area  60  483  402  357  177
# Rural Area  14  253  251  161   58

# %%
sns.heatmap(my_contingency_table)
# Out:
# <AxesSubplot:xlabel='bdbd_score', ylabel='pop_class'>

# %%
sns.heatmap(my_contingency_table, cmap="Reds")
# Out:
# <AxesSubplot:xlabel='bdbd_score', ylabel='pop_class'>

# %%
norm_con = pd.crosstab(index=bdbd_df["pop_class"], columns=bdbd_df["bdbd_score"], normalize="columns")*100
sns.heatmap(norm_con)
# Out:
# <AxesSubplot:xlabel='bdbd_score', ylabel='pop_class'>

# %%
plt.scatter(x = bdbd_df["broadband_pct"], y = bdbd_df["pop_total"]) # The plot
plt.title("Population Enrolled vs Broadband Percentage") # Adding a title
plt.xlabel("Broadband Percentage") # Adding axis labels
plt.ylabel("Total Population")
# Out:
# Text(0, 0.5, 'Total Population')
